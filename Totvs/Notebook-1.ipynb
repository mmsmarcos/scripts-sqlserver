-- %% [markdown]
-- Tabela de Coligadas

-- %%
USE CORPORE_EXEMPLO
GO
SELECT * FROM GCOLIGADA;
-- Out:
-- Commands completed successfully.
-- (4 rows affected)
-- Total execution time: 00:00:00.067
-- ...

-- %% [markdown]
-- SELECIONA A TABELA FILIAL

-- %%
SELECT * FROM GFILIAL;
-- Out:
-- (73 rows affected)
-- Total execution time: 00:00:00.028
-- ...
